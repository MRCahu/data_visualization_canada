# %% [markdown]
# # 📊 Projeto: Visualização de Dados de Imigração para o Canadá
# **Autor:** Mauro Roberto Barbosa Cahu
# **Objetivo:** Explorar e visualizar dados sobre imigração para o Canadá usando Python (Matplotlib, Seaborn e Plotly).
#
# ---

# %%
# 🔧 Etapa 1: Instalação e importação de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Exibir gráficos inline (para matplotlib e seaborn)
# %matplotlib inline
import os
print(os.getcwd())
# Out:
# g:\Meu Drive\mauro_projetos\DATA VISUALIZATION + PYTHON\data_visualization_canada\notebooks

# %%
import pandas as pd

df = pd.read_csv('../data/imigrantes_canada.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df = pd.read_csv('../data/imigrantes_canada.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index('País', inplace=True)
anos = list(map(str, range(1980, 2014)))

# %%
brasil = df.loc['Brasil', anos]
dados_brasil = pd.DataFrame({
    'ano': list(map(int, anos)),
    'imigrantes': brasil.values
})

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'], marker='o')
plt.title('Imigração do Brasil para o Canadá (1980–2013)')
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import plotly.express as px

fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigração do Brasil para o Canadá (1980–2013)',
              markers=True)
fig.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'], marker='o')
plt.title('Imigração do Brasil para o Canadá (1980–2013)')
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')
plt.grid(True)
plt.tight_layout()

# Salva antes de exibir
plt.savefig("grafico_brasil_canada.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Anos em string
anos = list(map(str, range(1980, 2014)))

# Dados dos dois países
brasil = df.loc['Brasil', anos]
argentina = df.loc['Argentina', anos]

# Criação da figura
plt.figure(figsize=(12, 6))

# Linha Brasil
plt.plot(anos, brasil, label='Brasil', marker='o')

# Linha Argentina
plt.plot(anos, argentina, label='Argentina', marker='s')

# Título e rótulos
plt.title('Imigração para o Canadá: Brasil vs Argentina (1980–2013)')
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')

# Ticks de 5 em 5 anos
plt.xticks(ticks=range(0, len(anos), 5), labels=anos[::5], rotation=45)

# Legenda
plt.legend()

# Grade e layout
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# prompt: IMPORTE/SALVE ESSA ÚLTIMO GRÁFICO

# Anos em string
anos = list(map(str, range(1980, 2014)))

# Dados dos dois países
brasil = df.loc['Brasil', anos]
argentina = df.loc['Argentina', anos]

# Criação da figura
plt.figure(figsize=(12, 6))

# Linha Brasil
plt.plot(anos, brasil, label='Brasil', marker='o')

# Linha Argentina
plt.plot(anos, argentina, label='Argentina', marker='s')

# Título e rótulos
plt.title('Imigração para o Canadá: Brasil vs Argentina (1980–2013)')
plt.xlabel('Ano')
plt.ylabel('Número de Imigrantes')

# Ticks de 5 em 5 anos
plt.xticks(ticks=range(0, len(anos), 5), labels=anos[::5], rotation=45)

# Legenda
plt.legend()

# Grade e layout
plt.grid(True)
plt.tight_layout()

# Salva o gráfico antes de exibir
plt.savefig("imigracao_brasil_argentina_canada.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

anos = list(map(int, range(1980, 2014)))

# Supondo que df tenha os dados com países no índice
brasil = df.loc['Brasil', list(map(str, anos))]
argentina = df.loc['Argentina', list(map(str, anos))]

# Criar figura com 1 linha e 2 colunas de gráficos
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Gráfico Brasil
ax1.plot(anos, brasil, marker='o', color='blue')
ax1.set_title('Imigração do Brasil')
ax1.set_xlabel('Ano')
ax1.set_ylabel('Número de Imigrantes')
ax1.xaxis.set_major_locator(plt.MultipleLocator(5))
ax1.grid(True)

# Gráfico Argentina
ax2.plot(anos, argentina, marker='s', color='green')
ax2.set_title('Imigração da Argentina')
ax2.set_xlabel('Ano')
ax2.set_ylabel('Número de Imigrantes')
ax2.xaxis.set_major_locator(plt.MultipleLocator(5))
ax2.grid(True)

plt.suptitle('Imigração para o Canadá (1980–2013): Brasil vs Argentina', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# prompt: IMPORTE/SALVE ESSA ÚLTIMO GRÁFICO

# Criar figura com 1 linha e 2 colunas de gráficos
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Gráfico Brasil
ax1.plot(anos, brasil, marker='o', color='blue')
ax1.set_title('Imigração do Brasil')
ax1.set_xlabel('Ano')
ax1.set_ylabel('Número de Imigrantes')
ax1.xaxis.set_major_locator(plt.MultipleLocator(5))
ax1.grid(True)

# Gráfico Argentina
ax2.plot(anos, argentina, marker='s', color='green')
ax2.set_title('Imigração da Argentina')
ax2.set_xlabel('Ano')
ax2.set_ylabel('Número de Imigrantes')
ax2.xaxis.set_major_locator(plt.MultipleLocator(5))
ax2.grid(True)

plt.suptitle('Imigração para o Canadá (1980–2013): Brasil vs Argentina', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Salva o gráfico antes de exibir
plt.savefig("imigracao_dois_paises_subplots.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exemplo de dados de imigração do Brasil
anos = list(range(1980, 2014))
imigrantes_brasil = df.loc['Brasil', list(map(str, anos))]

# Criar figura e eixo
fig, ax = plt.subplots(figsize=(10, 6))

# Plotar gráfico
ax.plot(anos, imigrantes_brasil, marker='o', color='blue')

# Título com quebra de linha
ax.set_title("Imigração do Brasil para o Canadá\n(1980 a 2013)", fontsize=14)

# Rótulos dos eixos
ax.set_xlabel("Ano")
ax.set_ylabel("Número de Imigrantes")

# Ticks personalizados
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# Grade
ax.grid(True)

# Exibir
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(anos, imigrantes_brasil, color='blue', label='Tendência')
ax.bar(anos, imigrantes_brasil, alpha=0.3, label='Valores por ano')
ax.set_title("Tendência e Total de Imigrantes\nBrasil para Canadá (1980–2013)")
ax.set_xlabel("Ano")
ax.set_ylabel("Imigrantes")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.show()

# %%
# prompt: SALVAR ESSE ÚLTIMO GRÁFICO

# O último gráfico plotado foi o que mostra a tendência e os valores por ano.
# Para salvar o último gráfico, você pode adicionar plt.savefig()
# antes de plt.show() no último bloco de código.

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(anos, imigrantes_brasil, color='blue', label='Tendência')
ax.bar(anos, imigrantes_brasil, alpha=0.3, label='Valores por ano')
ax.set_title("Tendência e Total de Imigrantes\nBrasil para Canadá (1980–2013)")
ax.set_xlabel("Ano")
ax.set_ylabel("Imigrantes")
ax.legend()
ax.grid(True)
plt.tight_layout()

# Salva o último gráfico antes de exibi-lo
plt.savefig("tendencia_total_imigracao_brasil.png", dpi=300)

plt.show()
